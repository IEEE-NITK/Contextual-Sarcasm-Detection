# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !unzip -uq "/content/drive/My Drive/CASCADE Trial/CASCADE.zip"

# %%
# !cat /proc/cpuinfo

# %%
# !pwd
# Out:
# /content

# %%
# %cd /content/CASCADE/users
# Out:
# /content/CASCADE/users

# %%
# !python create_per_user_paragraph.py
# Out:
# Grouping comments by user:   5% 579790/12704751 [00:08<02:51, 70872.57it/s]

# %%
# !pip install ijson
# Out:
# ...
#      |████████████████████████████████| 61kB 2.8MB/s
# ...

# %%
# !python train_stylometric.py
# Out:
# 2020-01-12 10:15:42,346 : INFO : collecting all words and their counts
# 2020-01-12 10:15:42,346 : INFO : PROGRESS: at example #0, processed 0 words (0/s), 0 word types, 0 tags
# 2020-01-12 10:15:42,867 : INFO : PROGRESS: at example #10000, processed 1511312 words (2905569/s), 102284 word types, 10000 tags
# 2020-01-12 10:15:43,171 : INFO : PROGRESS: at example #20000, processed 2393675 words (2906481/s), 133812 word types, 20000 tags
# 2020-01-12 10:15:43,414 : INFO : PROGRESS: at example #30000, processed 3109976 words (2941220/s), 155670 word types, 30000 tags
# 2020-01-12 10:15:43,605 : INFO : PROGRESS: at example #40000, processed 3598168 words (2571306/s), 170639 word types, 40000 tags
# 2020-01-12 10:15:43,831 : INFO : PROGRESS: at example #50000, processed 4186746 words (2604219/s), 185883 word types, 50000 tags
# 2020-01-12 10:15:44,045 : INFO : PROGRESS: at example #60000, processed 4551819 words (1702617/s), 195317 word types, 60000 tags
# ...
